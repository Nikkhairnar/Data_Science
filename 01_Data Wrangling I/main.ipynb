# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_excel(r"C:\Users\Lenovo\Desktop\Data Science Practicals\Data_Science\01_Data Wrangling I\Employees.xlsx")

# %%
dataset
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 0      1       Ghadir     Hmshw    Male 2018-04-04      2
# 1      2         Omar    Hishan    Male 2020-05-21      0
# 2      3        Ailya    Sharaf  Female 2017-09-28      3
# 3      4         Lwiy     Qbany    Male 2018-08-14      2
# 4      5        Ahmad     Bikri    Male 2020-03-11      0
# ..   ...          ...       ...     ...        ...    ...
# 684  685         Sari     Hanna    Male 2020-05-26      0
# 685  686      Eubayda      Kayd    Male 2020-06-03      0
# 686  687       Khalil    Alkalu    Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 0           Quality Control                 Egypt   West            1560
# 1           Quality Control          Saudi Arabia   West            3247
# ...

# %%
dataset.head()
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male 2018-04-04      2     Quality Control
# 1   2       Omar    Hishan    Male 2020-05-21      0     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      3  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male 2018-08-14      2       Manufacturing
# 4   5      Ahmad     Bikri    Male 2020-03-11      0       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# ...

# %%
dataset.tail()
# Out:
#       No   First Name Last Name Gender Start Date  Years  \
# 684  685         Sari     Hanna   Male 2020-05-26      0
# 685  686      Eubayda      Kayd   Male 2020-06-03      0
# 686  687       Khalil    Alkalu   Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy   Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar   Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 684               Marketing               Lebanon  South            1452
# 685  Facilities/Engineering                 Egypt  North            3237
# 686  Facilities/Engineering                 Egypt  North            2819
# 687                Creative                 Egypt  North            2069
# 688                      IT  United Arab Emirates  North            2606
#
#      Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# 684          17424       2.0            0              3               1
# ...

# %%
dataset.tail(10)
# Out:
#       No   First Name   Last Name  Gender Start Date  Years  \
# 679  680       Alysia  Alyaghshiu  Female 2019-10-19      1
# 680  681        Ayham      Alqadi    Male 2020-05-30      0
# 681  682         Diea     Shuelan    Male 2019-03-06      1
# 682  683        Husam      Alsaed    Male 2016-05-12      4
# 683  684          Asd     Bwfaeur    Male 2017-06-27      3
# 684  685         Sari       Hanna    Male 2020-05-26      0
# 685  686      Eubayda        Kayd    Male 2020-06-03      0
# 686  687       Khalil      Alkalu    Male 2017-07-11      3
# 687  688      Muhamad      Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit     AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 679                Training  United Arab Emirates   West            3334
# 680           Manufacturing                 Syria   East            2574
# 681           Manufacturing                 Egypt   West            1123
# ...

# %%
dataset.iloc[11]
# Out:
# No                                 12
# First Name                    Muhamad
# Last Name                         Iad
# Gender                           Male
# Start Date        2018-07-19 00:00:00
# Years                               2
# Department                         IT
# Country                         Egypt
# Center                           Main
# Monthly Salary                   2016
# Annual Salary                   24192
# Job Rate                          1.0
# Sick Leaves                         2
# Unpaid Leaves                       0
# Overtime Hours                     70
# Name: 11, dtype: object

# %%
dataset.iloc[-1]
# Out:
# No                                 689
# First Name                 Abd Albasit
# Last Name                      AlAhmar
# Gender                            Male
# Start Date         2020-08-05 00:00:00
# Years                                0
# Department                          IT
# Country           United Arab Emirates
# Center                           North
# Monthly Salary                    2606
# Annual Salary                    31272
# Job Rate                           5.0
# Sick Leaves                          0
# Unpaid Leaves                        0
# Overtime Hours                       0
# Name: 688, dtype: object

# %%
#to display particular rows
dataset.iloc[11:15]
# Out:
#     No First Name Last Name  Gender Start Date  Years              Department  \
# 11  12    Muhamad       Iad    Male 2018-07-19      2                      IT
# 12  13     Razaan     Nasif  Female 2018-11-11      2  Facilities/Engineering
# 13  14     Iilian       Dbs  Female 2016-03-01      4  Facilities/Engineering
# 14  15      Bayan       Qdw  Female 2018-12-04      2               Marketing
#
#                  Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 11                 Egypt   Main            2016          24192       1.0
# 12                 Egypt   Main            1999          23988       5.0
# 13  United Arab Emirates  North            3404          40848       5.0
# 14                 Egypt   Main             889          10668       3.0
#
#     Sick Leaves  Unpaid Leaves  Overtime Hours
# 11            2              0              70
# 12            6              0              85
# 13            1              0               8
# ...

# %%
dataset.iloc[[11],1:5]
# Out:
#    First Name Last Name Gender Start Date
# 11    Muhamad       Iad   Male 2018-07-19

# %%
#rows , columns
dataset.iloc[5:10,[0,4,6]]
# Out:
#    No Start Date           Department
# 5   6 2016-02-02  Product Development
# 6   7 2020-05-08                Sales
# 7   8 2018-02-10   Account Management
# 8   9 2018-03-11       Green Building
# 9  10 2020-01-03   Account Management

# %%
dataset.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
dataset.columns.values
# Out:
# array(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary',
#        'Annual Salary', 'Job Rate', 'Sick Leaves', 'Unpaid Leaves',
#        'Overtime Hours'], dtype=object)

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dataset[['Overtime Hours']])
# Out:
# pandas.core.frame.DataFrame

# %%
#sort first name in ascending order
dataset_new = dataset.sort_values('First Name',ascending=True)
dataset_new.head()
# Out:
#       No   First Name   Last Name Gender Start Date  Years  \
# 688  689  Abd Albasit     AlAhmar   Male 2020-08-05      0
# 55    56   Abd Alhadi    Alzzahir   Male 2018-03-14      2
# 562  563    Abd Allah     Aldahan   Male 2020-12-14      0
# 321  322    Abd Allah  Almawsiliu   Male 2018-08-10      2
# 41    42  Abd Allatif     Mabrukh   Male 2020-12-10      0
#
#                  Department               Country Center  Monthly Salary  \
# 688                      IT  United Arab Emirates  North            2606
# 55                    Sales                 Egypt  South            2679
# 562         Quality Control                 Egypt  North            3024
# 321                Creative          Saudi Arabia   West            2312
# 41   Facilities/Engineering                 Egypt  North            3344
#
#      Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# 688          31272       5.0            0              0               0
# ...

# %%
dataset_new = dataset.sort_values('First Name',ascending=False)
dataset_new.head()
# Out:
#       No First Name        Last Name  Gender Start Date  Years  \
# 157  158      Zunar             Eali    Male 2020-03-18      0
# 581  582     Zaynab            Eirat  Female 2019-12-26      1
# 37    38       Zayn  Aleabdyn Zaetar  Female 2020-11-29      0
# 120  121     Zaydun            Jabir    Male 2019-10-24      1
# 183  184   Zakarian         Rashwani    Male 2019-02-28      1
#
#               Department               Country Center  Monthly Salary  \
# 157   Major Mfg Projects                 Egypt  South            2127
# 581  Product Development  United Arab Emirates   Main             819
# 37       Quality Control  United Arab Emirates   West            2026
# 120        Manufacturing  United Arab Emirates   Main            2715
# 183        Manufacturing                 Syria   Main            2790
#
#      Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# 157          25524       5.0            0              0               3
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
dataset.isnull()
# Out:
#         No  First Name  Last Name  Gender  Start Date  Years  Department  \
# 0    False       False      False   False       False  False       False
# 1    False       False      False   False       False  False       False
# 2    False       False      False   False       False  False       False
# 3    False       False      False   False       False  False       False
# 4    False       False      False   False       False  False       False
# ..     ...         ...        ...     ...         ...    ...         ...
# 684  False       False      False   False       False  False       False
# 685  False       False      False   False       False  False       False
# 686  False       False      False   False       False  False       False
# 687  False       False      False   False       False  False       False
# 688  False       False      False   False       False  False       False
#
#      Country  Center  Monthly Salary  Annual Salary  Job Rate  Sick Leaves  \
# ...

# %%
dataset.isnull().iloc[:10]
# Out:
#       No  First Name  Last Name  Gender  Start Date  Years  Department  \
# 0  False       False      False   False       False  False       False
# 1  False       False      False   False       False  False       False
# 2  False       False      False   False       False  False       False
# 3  False       False      False   False       False  False       False
# 4  False       False      False   False       False  False       False
# 5  False       False      False   False       False  False       False
# 6  False       False      False   False       False  False       False
# 7  False       False      False   False       False  False       False
# 8  False       False      False   False       False  False       False
# 9  False       False      False   False       False  False       False
#
#    Country  Center  Monthly Salary  Annual Salary  Job Rate  Sick Leaves  \
# 0    False   False           False          False     False        False
# ...

# %%
dataset.isnull().sum()
# Out:
# No                0
# First Name        0
# Last Name         0
# Gender            0
# Start Date        0
# Years             0
# Department        0
# Country           0
# Center            0
# Monthly Salary    0
# Annual Salary     0
# Job Rate          0
# Sick Leaves       0
# Unpaid Leaves     0
# Overtime Hours    0
# dtype: int64

# %%
dataset.notnull().sum()
# Out:
# No                689
# First Name        689
# Last Name         689
# Gender            689
# Start Date        689
# Years             689
# Department        689
# Country           689
# Center            689
# Monthly Salary    689
# Annual Salary     689
# Job Rate          689
# Sick Leaves       689
# Unpaid Leaves     689
# Overtime Hours    689
# dtype: int64

# %%
dataset.describe()
# Out:
#                No                     Start Date       Years  Monthly Salary  \
# count  689.000000                            689  689.000000      689.000000
# mean   345.000000  2019-01-25 09:20:06.966618368    1.476052     2068.201742
# min      1.000000            2016-01-08 00:00:00    0.000000      703.000000
# 25%    173.000000            2018-04-05 00:00:00    1.000000     1436.000000
# 50%    345.000000            2019-04-03 00:00:00    1.000000     2077.000000
# 75%    517.000000            2019-12-22 00:00:00    2.000000     2682.000000
# max    689.000000            2020-12-29 00:00:00    5.000000     3450.000000
# std    199.041453                            NaN    1.190963      763.289240
#
#        Annual Salary    Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# count     689.000000  689.000000   689.000000     689.000000      689.000000
# mean    24818.420900    3.586357     1.609579       0.759071       13.702467
# ...

# %%
dataset.describe(percentiles=None,include=None,exclude=None)
# Out:
#                No                     Start Date       Years  Monthly Salary  \
# count  689.000000                            689  689.000000      689.000000
# mean   345.000000  2019-01-25 09:20:06.966618368    1.476052     2068.201742
# min      1.000000            2016-01-08 00:00:00    0.000000      703.000000
# 25%    173.000000            2018-04-05 00:00:00    1.000000     1436.000000
# 50%    345.000000            2019-04-03 00:00:00    1.000000     2077.000000
# 75%    517.000000            2019-12-22 00:00:00    2.000000     2682.000000
# max    689.000000            2020-12-29 00:00:00    5.000000     3450.000000
# std    199.041453                            NaN    1.190963      763.289240
#
#        Annual Salary    Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# count     689.000000  689.000000   689.000000     689.000000      689.000000
# mean    24818.420900    3.586357     1.609579       0.759071       13.702467
# ...

# %%
dataset.size
# Out:
# 10335

# %%
dataset.ndim
# Out:
# 2

# %%
dataset.shape
# Out:
# (689, 15)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Years           689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    int64
#  11  Job Rate        689 non-null    float64
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(6)
# memory usage: 80.9+ KB

# %% [markdown]
# ## Data Formatting and Data Normalization

# %%
dataset["Years"].astype(int)
# Out:
# 0      2
# 1      0
# 2      3
# 3      2
# 4      0
#       ..
# 684    0
# 685    0
# 686    3
# 687    2
# 688    0
# Name: Years, Length: 689, dtype: int64

# %%
dataset["Job Rate"]=dataset["Job Rate"].astype('datetime64[ns]')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Years           689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    int64
#  11  Job Rate        689 non-null    datetime64[ns]
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: datetime64[ns](2), int64(7), object(6)
# memory usage: 80.9+ KB

# %%
dataset["Monthly Salary"]=dataset["Monthly Salary"].astype(int)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Years           689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    int64
#  11  Job Rate        689 non-null    datetime64[ns]
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: datetime64[ns](2), int64(7), object(6)
# memory usage: 80.9+ KB

# %%
dataset.sort_values(by="Gender")
# Out:
#       No   First Name  Last Name  Gender Start Date  Years  \
# 210  211     Majdulyn    Alhakim  Female 2018-10-03      2
# 172  173         Ruaa     Mukiin  Female 2017-09-16      3
# 173  174         Rana    Shaeban  Female 2018-02-17      2
# 581  582       Zaynab      Eirat  Female 2019-12-26      1
# 175  176        Rahaf  Alaleppoy  Female 2020-04-18      0
# ..   ...          ...        ...     ...        ...    ...
# 265  266       Muayid      Shbyb    Male 2019-02-16      1
# 262  263      Muhamad     Alabth    Male 2019-09-23      1
# 261  262       Thamir  Abu Ghazy    Male 2018-03-12      2
# 284  285        Adnan   Alhusayn    Male 2018-04-09      2
# 688  689  Abd Albasit    AlAhmar    Male 2020-08-05      0
#
#               Department               Country Center  Monthly Salary  \
# 210      Human Resources                 Egypt   Main            3093
# 172        Manufacturing          Saudi Arabia   Main            3168
# ...

# %%
dataset.T
# Out:
#                                           0                              1    \
# No                                          1                              2
# First Name                             Ghadir                           Omar
# Last Name                               Hmshw                         Hishan
# Gender                                   Male                           Male
# Start Date                2018-04-04 00:00:00            2020-05-21 00:00:00
# Years                                       2                              0
# Department                    Quality Control                Quality Control
# Country                                 Egypt                   Saudi Arabia
# Center                                   West                           West
# Monthly Salary                           1560                           3247
# Annual Salary                           18720                          38964
# ...

# %%
dataset.isnull().values.any()
# Out:
# np.False_

# %%
dataset.iloc[1:10]
# Out:
#    No First Name  Last Name  Gender Start Date  Years           Department  \
# 1   2       Omar     Hishan    Male 2020-05-21      0      Quality Control
# 2   3      Ailya     Sharaf  Female 2017-09-28      3   Major Mfg Projects
# 3   4       Lwiy      Qbany    Male 2018-08-14      2        Manufacturing
# 4   5      Ahmad      Bikri    Male 2020-03-11      0        Manufacturing
# 5   6    Muhamad     Zueitr    Male 2016-02-02      4  Product Development
# 6   7        Iin  Alhalaliu  Female 2020-05-08      0                Sales
# 7   8    Muhamad      Alaya    Male 2018-02-10      2   Account Management
# 8   9      Susin    Almilat  Female 2018-03-11      2       Green Building
# 9  10    Muhamad   Alrifaei    Male 2020-01-03      1   Account Management
#
#                 Country Center  Monthly Salary  Annual Salary  \
# 1          Saudi Arabia   West            3247          38964
# 2          Saudi Arabia   West            2506          30072
# ...

# %%
dataset.iloc[1:3, :]
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 1   2       Omar    Hishan    Male 2020-05-21      0     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      3  Major Mfg Projects
#
#         Country Center  Monthly Salary  Annual Salary  \
# 1  Saudi Arabia   West            3247          38964
# 2  Saudi Arabia   West            2506          30072
#
#                        Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# 1 1970-01-01 00:00:00.000000001            0              5             198
# 2 1970-01-01 00:00:00.000000002            0              3             192

# %%
dataset.iloc[3:5,0:2]
# Out:
#    No First Name
# 3   4       Lwiy
# 4   5      Ahmad

# %%
dataset.iloc[[1,2,4],[0,2]]
# Out:
#    No Last Name
# 1   2    Hishan
# 2   3    Sharaf
# 4   5     Bikri

# %%
dataset['First Name'].iloc[4]
# Out:
# 'Ahmad'

# %%
dataset.iloc[4,1]
# Out:
# 'Ahmad'

# %%
dataset[['First Name','Center']]
# Out:
#       First Name Center
# 0         Ghadir   West
# 1           Omar   West
# 2          Ailya   West
# 3           Lwiy   Main
# 4          Ahmad   Main
# ..           ...    ...
# 684         Sari  South
# 685      Eubayda  North
# 686       Khalil  North
# 687      Muhamad  North
# 688  Abd Albasit  North
#
# [689 rows x 2 columns]

# %%
#Get Column Name
cols_2_6=dataset.columns[2:6]
cols_2_6
# Out:
# Index(['Last Name', 'Gender', 'Start Date', 'Years'], dtype='object')

# %%
dataset[cols_2_6]
# Out:
#     Last Name  Gender Start Date  Years
# 0       Hmshw    Male 2018-04-04      2
# 1      Hishan    Male 2020-05-21      0
# 2      Sharaf  Female 2017-09-28      3
# 3       Qbany    Male 2018-08-14      2
# 4       Bikri    Male 2020-03-11      0
# ..        ...     ...        ...    ...
# 684     Hanna    Male 2020-05-26      0
# 685      Kayd    Male 2020-06-03      0
# 686    Alkalu    Male 2017-07-11      3
# 687    Shrbjy    Male 2018-05-30      2
# 688   AlAhmar    Male 2020-08-05      0
#
# [689 rows x 4 columns]

# %%
dataset[cols_2_6].iloc[5:10]
# Out:
#    Last Name  Gender Start Date  Years
# 5     Zueitr    Male 2016-02-02      4
# 6  Alhalaliu  Female 2020-05-08      0
# 7      Alaya    Male 2018-02-10      2
# 8    Almilat  Female 2018-03-11      2
# 9   Alrifaei    Male 2020-01-03      1

# %%
#dataset contains a lot of non-numeric columns,so will give error
dataset.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[235], line 2
#       1 #dataset contains a lot of non-numeric columns,so will give error
# ----> 2 dataset.mean()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)  11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
# ...

# %%
dataset.mode()
# Out:
#       No First Name Last Name Gender Start Date  Years     Department Country  \
# 0      1    Muhamad   Almisri   Male 2018-02-05    1.0  Manufacturing   Egypt
# 1      2        NaN       NaN    NaN 2018-04-04    NaN            NaN     NaN
# 2      3        NaN       NaN    NaN 2018-05-30    NaN            NaN     NaN
# 3      4        NaN       NaN    NaN 2018-06-14    NaN            NaN     NaN
# 4      5        NaN       NaN    NaN 2018-09-05    NaN            NaN     NaN
# ..   ...        ...       ...    ...        ...    ...            ...     ...
# 684  685        NaN       NaN    NaN        NaT    NaN            NaN     NaN
# 685  686        NaN       NaN    NaN        NaT    NaN            NaN     NaN
# 686  687        NaN       NaN    NaN        NaT    NaN            NaN     NaN
# 687  688        NaN       NaN    NaN        NaT    NaN            NaN     NaN
# 688  689        NaN       NaN    NaN        NaT    NaN            NaN     NaN
#
# ...

# %%
#error
dataset.median()

# %%
dataset["Annual Salary"]=9/dataset["Annual Salary"]
dataset.iloc[5:10]
# Out:
#    No First Name  Last Name  Gender Start Date  Years           Department  \
# 5   6    Muhamad     Zueitr    Male 2016-02-02      4  Product Development
# 6   7        Iin  Alhalaliu  Female 2020-05-08      0                Sales
# 7   8    Muhamad      Alaya    Male 2018-02-10      2   Account Management
# 8   9      Susin    Almilat  Female 2018-03-11      2       Green Building
# 9  10    Muhamad   Alrifaei    Male 2020-01-03      1   Account Management
#
#                 Country Center  Monthly Salary  Annual Salary  \
# 5          Saudi Arabia  North            2332       0.000322
# 6  United Arab Emirates   Main            1959       0.000383
# 7                 Egypt   Main            3394       0.000221
# 8                 Egypt  North            1479       0.000507
# 9                 Egypt   Main            1186       0.000632
#
#                        Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# ...

# %%
dataset.rename(columns={"Years":"Overall Years"},inplace=True)
dataset.iloc[5:10]
# Out:
#    No First Name  Last Name  Gender Start Date  Overall Years  \
# 5   6    Muhamad     Zueitr    Male 2016-02-02              4
# 6   7        Iin  Alhalaliu  Female 2020-05-08              0
# 7   8    Muhamad      Alaya    Male 2018-02-10              2
# 8   9      Susin    Almilat  Female 2018-03-11              2
# 9  10    Muhamad   Alrifaei    Male 2020-01-03              1
#
#             Department               Country Center  Monthly Salary  \
# 5  Product Development          Saudi Arabia  North            2332
# 6                Sales  United Arab Emirates   Main            1959
# 7   Account Management                 Egypt   Main            3394
# 8       Green Building                 Egypt  North            1479
# 9   Account Management                 Egypt   Main            1186
#
#    Annual Salary                      Job Rate  Sick Leaves  Unpaid Leaves  \
# 5       0.000322 1970-01-01 00:00:00.000000003            3              0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Overall Years   689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    float64
#  11  Job Rate        689 non-null    datetime64[ns]
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: datetime64[ns](2), float64(1), int64(6), object(6)
# memory usage: 80.9+ KB

# %%
dataset["Overall Years"]=dataset["Overall Years"].astype("complex64")
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Overall Years   689 non-null    complex64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    float64
#  11  Job Rate        689 non-null    datetime64[ns]
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: complex64(1), datetime64[ns](2), float64(1), int64(5), object(6)
# ...

# %% [markdown]
# ## Evaluating for Missing Data

# %%
dataset.iloc[1:3, :]
# Out:
#    No First Name Last Name  Gender Start Date  Overall Years  \
# 1   2       Omar    Hishan    Male 2020-05-21       0.0+0.0j
# 2   3      Ailya    Sharaf  Female 2017-09-28       3.0+0.0j
#
#            Department       Country Center  Monthly Salary  Annual Salary  \
# 1     Quality Control  Saudi Arabia   West            3247       0.000231
# 2  Major Mfg Projects  Saudi Arabia   West            2506       0.000299
#
#                        Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# 1 1970-01-01 00:00:00.000000001            0              5             198
# 2 1970-01-01 00:00:00.000000002            0              3             192

# %%
x=dataset["Gender"].mode()
x
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
dataset["Gender"]=dataset["Gender"].fillna("Male")
dataset.tail()
# Out:
#       No   First Name Last Name Gender Start Date  Overall Years  \
# 684  685         Sari     Hanna   Male 2020-05-26       0.0+0.0j
# 685  686      Eubayda      Kayd   Male 2020-06-03       0.0+0.0j
# 686  687       Khalil    Alkalu   Male 2017-07-11       3.0+0.0j
# 687  688      Muhamad    Shrbjy   Male 2018-05-30       2.0+0.0j
# 688  689  Abd Albasit   AlAhmar   Male 2020-08-05       0.0+0.0j
#
#                  Department               Country Center  Monthly Salary  \
# 684               Marketing               Lebanon  South            1452
# 685  Facilities/Engineering                 Egypt  North            3237
# 686  Facilities/Engineering                 Egypt  North            2819
# 687                Creative                 Egypt  North            2069
# 688                      IT  United Arab Emirates  North            2606
#
#      Annual Salary                      Job Rate  Sick Leaves  Unpaid Leaves  \
# ...

# %%
dataset.iloc[:20]
# Out:
#     No First Name    Last Name  Gender Start Date  Overall Years  \
# 0    1     Ghadir        Hmshw    Male 2018-04-04       2.0+0.0j
# 1    2       Omar       Hishan    Male 2020-05-21       0.0+0.0j
# 2    3      Ailya       Sharaf  Female 2017-09-28       3.0+0.0j
# 3    4       Lwiy        Qbany    Male 2018-08-14       2.0+0.0j
# 4    5      Ahmad        Bikri    Male 2020-03-11       0.0+0.0j
# 5    6    Muhamad       Zueitr    Male 2016-02-02       4.0+0.0j
# 6    7        Iin    Alhalaliu  Female 2020-05-08       0.0+0.0j
# 7    8    Muhamad        Alaya    Male 2018-02-10       2.0+0.0j
# 8    9      Susin      Almilat  Female 2018-03-11       2.0+0.0j
# 9   10    Muhamad     Alrifaei    Male 2020-01-03       1.0+0.0j
# 10  11    Muhamad      Alqadah    Male 2018-01-16       2.0+0.0j
# 11  12    Muhamad          Iad    Male 2018-07-19       2.0+0.0j
# 12  13     Razaan        Nasif  Female 2018-11-11       2.0+0.0j
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Overall Years   689 non-null    complex64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    float64
#  11  Job Rate        689 non-null    datetime64[ns]
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: complex64(1), datetime64[ns](2), float64(1), int64(5), object(6)
# ...

# %%
dataset.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date',
#        'Overall Years', 'Department', 'Country', 'Center', 'Monthly Salary',
#        'Annual Salary', 'Job Rate', 'Sick Leaves', 'Unpaid Leaves',
#        'Overtime Hours'],
#       dtype='object')

# %%
dataset['First Name']=dataset['First Name'].fillna('Unknown')
dataset.head(5)
# Out:
#    No First Name Last Name  Gender Start Date  Overall Years  \
# 0   1     Ghadir     Hmshw    Male 2018-04-04       2.0+0.0j
# 1   2       Omar    Hishan    Male 2020-05-21       0.0+0.0j
# 2   3      Ailya    Sharaf  Female 2017-09-28       3.0+0.0j
# 3   4       Lwiy     Qbany    Male 2018-08-14       2.0+0.0j
# 4   5      Ahmad     Bikri    Male 2020-03-11       0.0+0.0j
#
#            Department               Country Center  Monthly Salary  \
# 0     Quality Control                 Egypt   West            1560
# 1     Quality Control          Saudi Arabia   West            3247
# 2  Major Mfg Projects          Saudi Arabia   West            2506
# 3       Manufacturing  United Arab Emirates   Main            1828
# 4       Manufacturing                 Egypt   Main             970
#
#    Annual Salary                      Job Rate  Sick Leaves  Unpaid Leaves  \
# 0       0.000481 1970-01-01 00:00:00.000000003            1              0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Overall Years   689 non-null    complex64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    float64
#  11  Job Rate        689 non-null    datetime64[ns]
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: complex64(1), datetime64[ns](2), float64(1), int64(5), object(6)
# ...

# %%
dataset.shape
# Out:
# (689, 15)

# %%
dataset=dataset.dropna()
dataset.iloc[:15]
# Out:
#     No First Name  Last Name  Gender Start Date  Overall Years  \
# 0    1     Ghadir      Hmshw    Male 2018-04-04       2.0+0.0j
# 1    2       Omar     Hishan    Male 2020-05-21       0.0+0.0j
# 2    3      Ailya     Sharaf  Female 2017-09-28       3.0+0.0j
# 3    4       Lwiy      Qbany    Male 2018-08-14       2.0+0.0j
# 4    5      Ahmad      Bikri    Male 2020-03-11       0.0+0.0j
# 5    6    Muhamad     Zueitr    Male 2016-02-02       4.0+0.0j
# 6    7        Iin  Alhalaliu  Female 2020-05-08       0.0+0.0j
# 7    8    Muhamad      Alaya    Male 2018-02-10       2.0+0.0j
# 8    9      Susin    Almilat  Female 2018-03-11       2.0+0.0j
# 9   10    Muhamad   Alrifaei    Male 2020-01-03       1.0+0.0j
# 10  11    Muhamad    Alqadah    Male 2018-01-16       2.0+0.0j
# 11  12    Muhamad        Iad    Male 2018-07-19       2.0+0.0j
# 12  13     Razaan      Nasif  Female 2018-11-11       2.0+0.0j
# 13  14     Iilian        Dbs  Female 2016-03-01       4.0+0.0j
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Overall Years   689 non-null    complex64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    float64
#  11  Job Rate        689 non-null    datetime64[ns]
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: complex64(1), datetime64[ns](2), float64(1), int64(5), object(6)
# ...

# %%
dataset["Gender"]=dataset["Gender"].replace({"Female":0,"Male":1})

# %%
dataset.iloc[:25]
# Out:
#     No First Name    Last Name  Gender Start Date  Overall Years  \
# 0    1     Ghadir        Hmshw       1 2018-04-04       2.0+0.0j
# 1    2       Omar       Hishan       1 2020-05-21       0.0+0.0j
# 2    3      Ailya       Sharaf       0 2017-09-28       3.0+0.0j
# 3    4       Lwiy        Qbany       1 2018-08-14       2.0+0.0j
# 4    5      Ahmad        Bikri       1 2020-03-11       0.0+0.0j
# 5    6    Muhamad       Zueitr       1 2016-02-02       4.0+0.0j
# 6    7        Iin    Alhalaliu       0 2020-05-08       0.0+0.0j
# 7    8    Muhamad        Alaya       1 2018-02-10       2.0+0.0j
# 8    9      Susin      Almilat       0 2018-03-11       2.0+0.0j
# 9   10    Muhamad     Alrifaei       1 2020-01-03       1.0+0.0j
# 10  11    Muhamad      Alqadah       1 2018-01-16       2.0+0.0j
# 11  12    Muhamad          Iad       1 2018-07-19       2.0+0.0j
# 12  13     Razaan        Nasif       0 2018-11-11       2.0+0.0j
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    int64
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Overall Years   689 non-null    complex64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    float64
#  11  Job Rate        689 non-null    datetime64[ns]
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: complex64(1), datetime64[ns](2), float64(1), int64(6), object(5)
# ...

# %%
dataset.head()
# Out:
#    No First Name Last Name  Gender Start Date  Overall Years  \
# 0   1     Ghadir     Hmshw       1 2018-04-04       2.0+0.0j
# 1   2       Omar    Hishan       1 2020-05-21       0.0+0.0j
# 2   3      Ailya    Sharaf       0 2017-09-28       3.0+0.0j
# 3   4       Lwiy     Qbany       1 2018-08-14       2.0+0.0j
# 4   5      Ahmad     Bikri       1 2020-03-11       0.0+0.0j
#
#            Department               Country Center  Monthly Salary  \
# 0     Quality Control                 Egypt   West            1560
# 1     Quality Control          Saudi Arabia   West            3247
# 2  Major Mfg Projects          Saudi Arabia   West            2506
# 3       Manufacturing  United Arab Emirates   Main            1828
# 4       Manufacturing                 Egypt   Main             970
#
#    Annual Salary                      Job Rate  Sick Leaves  Unpaid Leaves  \
# 0       0.000481 1970-01-01 00:00:00.000000003            1              0
# ...

# %% [markdown]
# ## Normalization of Data

# %%
x = dataset[['Monthly Salary']]
x
# Out:
#      Monthly Salary
# 0              1560
# 1              3247
# 2              2506
# 3              1828
# 4               970
# ..              ...
# 684            1452
# 685            3237
# 686            2819
# 687            2069
# 688            2606
#
# [689 rows x 1 columns]

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x_scale = min_max_scaler.fit_transform(x)

# %%
df_normalized = pd.DataFrame(x_scale)
df_normalized
# Out:
#             0
# 0    0.311977
# 1    0.926101
# 2    0.656352
# 3    0.409538
# 4    0.097197
# ..        ...
# 684  0.272661
# 685  0.922461
# 686  0.770295
# 687  0.497270
# 688  0.692756
#
# [689 rows x 1 columns]

# %%
dataset[['Monthly Salary']].max()
# Out:
# Monthly Salary    3450
# dtype: int64

# %%
dataset[['Monthly Salary']].min()
# Out:
# Monthly Salary    703
# dtype: int64

# %%
y = df_normalized

# %%
y = y.head(10)
y
# Out:
#           0
# 0  0.311977
# 1  0.926101
# 2  0.656352
# 3  0.409538
# 4  0.097197
# 5  0.593011
# 6  0.457226
# 7  0.979614
# 8  0.282490
# 9  0.175828

# %%
y.plot(kind='bar')
# Out:
# <Axes: >
